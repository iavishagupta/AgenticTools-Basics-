# %% [markdown]
# <a href="https://colab.research.google.com/github/iavishagupta/CrewAI-AgenticTools/blob/main/AutomatedDataAnalysisTeam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install crewai_tools > /dev/null
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.

# %%
import os

os.environ["CREWAI_NO_WIDGETS"] = "1"
os.environ["CREWAI_HEADLESS"] = "1"
os.environ["SERPER_API_KEY"] = "YOUR_API_KEY"
os.environ["OPENAI_API_KEY"] = "YOUR_API_KEY"
os.environ["OPENAI_MODEL_NAME"] = "gpt-3.5-turbo"

# %%
from crewai import Agent, Task, Crew, Process
from crewai_tools import SerperDevTool

# %%
data_collector = Agent(
    role='Data Collector',
    goal='Gather relevant data from various sources. And organize them in a structured manner for beter analysis, query-response, and retrieval.',
    backstory='Experienced in collecting data from various sources.',
    verbose=True,
    tools=[SerperDevTool()]

)

data_analyst = Agent(
    role='Data Analyst',
    goal='Analyze collected data to extract insights. Understand the pattern of the data, and predict any future queries if relevant to the data\'s topic and asked by the user to do so.',
    backstory='Proficient in data analysis and interpretation.',
    verbose=True
)

# %%
topic = "Recent Gold Rate Trends"
collect_data_task = Task(
    description=f'Collect data on the specified topic. Topic:{topic}',
    agent=data_collector,
    expected_output='Raw data collected from various sources. Structured in a good manner in points.'
)

analyze_data_task = Task(
    description='Analyze the collected data to extract meaningful insights. And predict the Gold Rates for the next 6 months.',
    agent=data_analyst,
    expected_output='Insights derived from the data analysis. And the next 6 month prediction',
    context=[collect_data_task]
)

# %%
data_analysis_crew = Crew(
    agents=[data_collector, data_analyst],
    tasks=[collect_data_task, analyze_data_task],
    process=Process.sequential,
    verbose=True
)

result=data_analysis_crew.kickoff()
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 6031a886-6e52-49c5-93c1-7b7abd71821e                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Data Collector                                                                                          │
# │                                                                                                                 │
# │  Task: Collect data on the specified topic. Topic:Recent Gold Rate Trends                                       │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Data Collector                                                                                          │
# │                                                                                                                 │
# │  Thought: I should start by searching the internet for recent gold rate trends in order to collect raw data     │
# │  from various sources and structure it in points for better analysis.                                           │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {                                                                                                              │
# │    "search_query": "Recent Gold Rate Trends"                                                                    │
# │  }                                                                                                              │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {'searchParameters': {'q': 'Recent Gold Rate Trends', 'type': 'search', 'num': 10, 'engine': 'google'},        │
# │  'organic': [{'title': 'Gold - Price - Chart - Historical Data - News - Trading Economics', 'link':             │
# │  'https://tradingeconomics.com/commodity/gold', 'snippet': "Gold fell to 4163.26 USD/t.oz on November 14,       │
# │  2025, down 0.18% from the previous day. Over the past month, Gold's price has fallen 1.08%, but it is still    │
# │  ...", 'position': 1}, {'title': 'Live Gold Spot Price Chart | BullionVault', 'link':                           │
# │  'https://www.bullionvault.com/gold-price-chart.do', 'snippet': "Currently, the US dollar spot price for 1      │
# │  ounce of gold is $4,193.28 and in Canadian dollars C$5,879.58. However, it's possible to track the real-time   │
# │  changing ...", 'position': 2, 'sitelinks': [{'title': 'Gold Investment', 'link':                               │
# │  'https://www.bullionvault.com/gold-guide/gold-investment'}, {'title': 'Gold News', 'link':                     │
# │  'https://www.bullionvault.com/gold-news'}, {'title': 'Gold Price News', 'link':                                │
# │  'https://www.bullionvault.com/gold-news/gold-price-news'}, {'title': '$37 Silver Splits from Gold Price',      │
# │  'link': 'https://www.bullionvault.com/gold-news/gold-price-news/silver-price-gold-061720251'}]}, {'title':     │
# │  'Gold Price Today - Live Gold Spot Price Charts - JM Bullion', 'link':                                         │
# │  'https://www.jmbullion.com/charts/gold-price/', 'snippet': 'Gold is trading around $4,217 per ounce, marking   │
# │  a fresh high for the session and extending a rally that has carried prices higher over the past few days as    │
# │  ...', 'position': 3}, {'title': 'Gold Price Today | Gold Spot Price Charts - APMEX', 'link':                   │
# │  'https://www.apmex.com/gold-price', 'snippet': "Gold's current record high was achieved on April 22nd, 2025,   │
# │  at $3,500.20 per troy ounce. This follows a trend of new record-setting highs for gold ...", 'position': 4,    │
# │  'sitelinks': [{'title': 'Gold Buffalo Values', 'link':                                                         │
# │  'https://www.apmex.com/gold-price/gold-buffalo-value-chart'}, {'title': 'Gold Maple Values', 'link':           │
# │  'https://www.apmex.com/gold-price/gold-maple-value-chart'}, {'...                                              │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Data Collector                                                                                          │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  - Gold fell to $4,163.26 USD/t.oz on November 14, 2025, down 0.18% from the previous day.                      │
# │  - The current spot price for 1 ounce of gold is $4,193.28 USD in the US dollar and C$5,879.58 in Canadian      │
# │  dollars.                                                                                                       │
# │  - Gold is trading around $4,217 per ounce, marking a fresh high for the session.                               │
# │  - Gold's current record high was achieved on April 22nd, 2025, at $3,500.20 per troy ounce.                    │
# │  - Live Gold Spot Prices: $4,213.00 per ounce, $135.45 per gram, and $135,447.95 per kilo.                      │
# │  - The price of gold has virtually experienced a surge in recent years, passing $1,000 per ounce.               │
# │  - Annual Gold Prices since 1970:                                                                               │
# │    - 2020: $1,771.07 (high) and $1,518.34 (low)                                                                 │
# │    - 2019: $1,393.86 (high) and $1,282.55 (low)                                                                 │
# │    - 2018: $1,269.69 (high) and $1,302.42 (low)                                                                 │
# │    - 2017: $1,258.70 (high) and $1,152.00 (low)                                                                 │
# │  - Gold Price History available for different timeframes.                                                       │
# │  - Current Gold Futures Price: $4,181.47 with a previous close of $4,194.50.                                    │
# │  - Experts remain bullish on gold, with price targets ranging from $4,200 to $4,700 per ounce.                  │
# │  - Recent search queries related to gold rate trends include variations like trends in the USA, 24 carat        │
# │  trends, historical chart, 10-year chart, last 30 days chart, and silver prices.                                │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: fd564c42-4db7-4fad-9aa3-3b7245ed7d92                                                                     │
# │  Agent: Data Collector                                                                                          │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Data Analyst                                                                                            │
# │                                                                                                                 │
# │  Task: Analyze the collected data to extract meaningful insights. And predict the Gold Rates for the next 6     │
# │  months.                                                                                                        │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Data Analyst                                                                                            │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Insights:                                                                                                      │
# │  1. The price of gold has shown a steady increase over the years, surpassing the $1,000 mark and reaching       │
# │  record highs.                                                                                                  │
# │  2. Experts are optimistic about the future of gold, with price targets ranging from $4,200 to $4,700 per       │
# │  ounce.                                                                                                         │
# │  3. Gold's current spot price is $4,193.28 USD in the US dollar and C$5,879.58 in Canadian dollars, while       │
# │  trading at around $4,217 per ounce.                                                                            │
# │  4. Recent search queries indicate an interest in gold rate trends, including historical charts and silver      │
# │  prices.                                                                                                        │
# │                                                                                                                 │
# │  Prediction for Gold Rates for the next 6 months:                                                               │
# │  Based on the current data and expert predictions, it is likely that the price of gold will continue to rise    │
# │  steadily over the next 6 months. Factors such as economic uncertainties, inflation concerns, and geopolitical  │
# │  tensions may further boost the demand for gold as a safe-haven asset. Therefore, it is reasonable to expect    │
# │  that the gold rates could range between $4,500 to $5,000 per ounce in the next 6 months. However,              │
# │  fluctuations in the global market conditions may impact the actual prices.                                     │
# │                                                                                                                 │
# │  Overall, the outlook for gold rates appears positive, and investors may consider this trend while making       │
# │  investment decisions in the precious metal.                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
with open("GoldRateAnalysis.txt", "w") as f:
    f.write(result.raw)

# %%
with open("GoldRateAnalysis.txt", "r") as f:
    print(f.read())
# Out:
# Insights:
# 1. The price of gold has shown a steady increase over the years, surpassing the $1,000 mark and reaching record highs.
# 2. Experts are optimistic about the future of gold, with price targets ranging from $4,200 to $4,700 per ounce.
# 3. Gold's current spot price is $4,193.28 USD in the US dollar and C$5,879.58 in Canadian dollars, while trading at around $4,217 per ounce.
# 4. Recent search queries indicate an interest in gold rate trends, including historical charts and silver prices.
#
# Prediction for Gold Rates for the next 6 months:
# Based on the current data and expert predictions, it is likely that the price of gold will continue to rise steadily over the next 6 months. Factors such as economic uncertainties, inflation concerns, and geopolitical tensions may further boost the demand for gold as a safe-haven asset. Therefore, it is reasonable to expect that the gold rates could range between $4,500 to $5,000 per ounce in the next 6 months. However, fluctuations in the global market conditions may impact the actual prices.
#
# Overall, the outlook for gold rates appears positive, and investors may consider this trend while making investment decisions in the precious metal.
